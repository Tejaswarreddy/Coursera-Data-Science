# %% [markdown]
# # My Jupyter Notebook on Watson Studio

# %% [markdown]
# **Kusam Tejaswar Reddy**<br>
# Student

# %% [markdown]
# *I am interested in data sceince because i'm so curious in finding something new and finding patterns. I think it driven me to data science*

# %% [markdown]
# ### My code is abot to print something called Hello Peers

# %%
print("Hello Peers and Thank you for reviewing my assignment")
# Out:
# Hello Peers and Thank you for reviewing my assignment

# %% [markdown]
# ------
# * Bullet List1
# * Item2
# * Item3
#
# 1. Numbered Listitem1
# 2. Item2
# 3. Item3
#
# | head | head |
# |------|------|
# | row1 | row 1|
